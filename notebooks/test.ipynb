# %%
import yaml

with open(r"C:\Users\nours\Documents\Gym Python Project\configs\db.yml", "r") as f:
        config = yaml.safe_load(f)

# %%
config['tables']['gym_sessions']['columns'][1]['excel_column']
# Out:
# 'Day'

# %%
import sqlite3

conn = sqlite3.connect(r"C:\Users\nours\Documents\Gym Python Project\db\gym_data.db")
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM gym_sessions")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, '2025-03-13 00:00:00', None, 'Olympic Gym', 'Cardio & Core')
# (2, '2025-03-18 00:00:00', None, 'Olympic Gym', 'Lowerday')
# (3, '2025-03-21 00:00:00', None, 'Olympic Gym', 'Upperday')
# (4, '2025-03-25 00:00:00', None, 'Olympic Gym', 'Cardio & Core')
# (5, '2025-03-26 00:00:00', None, 'Olympic Gym', 'Lowerday')
# (6, '2025-03-27 00:00:00', None, 'Olympic Gym', 'PT')
# (7, '2025-04-01 00:00:00', None, 'Olympic Gym', 'Upperday')
# (8, '2025-04-03 00:00:00', None, 'Olympic Gym', 'Cardio & Core')
# (9, '2025-04-04 00:00:00', None, 'Olympic Gym', 'PT')
# (10, '2025-04-06 00:00:00', None, 'Olympic Gym', 'Lowerday')
# (11, '2025-04-08 00:00:00', None, 'Olympic Gym', 'Upperday')
# (12, '2025-04-12 00:00:00', None, 'Olympic Gym', 'Cardio & Core')
# (13, '2025-04-13 00:00:00', None, 'Olympic Gym', 'Lowerday')
# (14, '2025-04-16 00:00:00', None, 'Olympic Gym', 'Upperday')
# (15, '2025-04-18 00:00:00', None, 'Olympic Gym', 'PT')
# ...
